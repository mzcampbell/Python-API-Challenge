# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 628

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lebu
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | sheltozero
# Processing Record 4 of Set 1 | damaturu
# Processing Record 5 of Set 1 | ilo
# Processing Record 6 of Set 1 | solnechnyy
# Processing Record 7 of Set 1 | nome
# Processing Record 8 of Set 1 | qeshm
# Processing Record 9 of Set 1 | norman wells
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | micheweni
# Processing Record 14 of Set 1 | labuhan
# Processing Record 15 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | urumqi
# Processing Record 18 of Set 1 | fortuna
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | aginskoye
# Processing Record 22 of Set 1 | senneterre
# Processing Record 23 of Set 1 | daru
# Processing Record 24 of Set 1 | sistranda
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | praia
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | dobsice
# Processing Record 29 of Set 1 | jardinopolis
# Processing Record 30 of Set 1 | diffa
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | outjo
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | kristiinankaupunki
# Processing Record 35 of Set 1 | fairbanks
# Processing Record 36 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 1 | longyearbyen
# Processing Record 38 of Set 1 | gat
# Processing Record 39 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | la ronge
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | katangli
# Processing Record 46 of Set 1 | ancud
# Processing Record 47 of Set 1 | nioro
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | cocorit
# Processing Record 50 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 0 of Set 2 | ushuaia
# Processing Record 1 of Set 2 | kaitangata
# Processing Record 2 of Set 2 | port lincoln
# Processing Record 3 of Set 2 | kamaishi
# Processing Record 4 of Set 2 | drumheller
# Processing Record 5 of Set 2 | halifax
# Processing Record 6 of Set 2 | malakal
# Processing Record 7 of Set 2 | okhotsk
# Processing Record 8 of Set 2 | marsa matruh
# Processing Record 9 of Set 2 | tazovskiy
# Processing Record 10 of Set 2 | bengkulu
# Processing Record 11 of Set 2 | sao joao da barra
# Processing Record 12 of Set 2 | huilong
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | kasongo
# Processing Record 17 of Set 2 | dolores
# Processing Record 18 of Set 2 | port blair
# Processing Record 19 of Set 2 | samana
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | chuguyevka
# Processing Record 22 of Set 2 | homer
# Processing Record 23 of Set 2 | vaini
# Processing Record 24 of Set 2 | kruisfontein
# Processing Record 25 of Set 2 | bugene
# Processing Record 26 of Set 2 | biharamulo
# Processing Record 27 of Set 2 | viedma
# Processing Record 28 of Set 2 | malm
# Processing Record 29 of Set 2 | jining
# Processing Record 30 of Set 2 | chistogorskiy
# Processing Record 31 of Set 2 | nianzishan
# Processing Record 32 of Set 2 | necochea
# Processing Record 33 of Set 2 | berovo
# Processing Record 34 of Set 2 | standerton
# Processing Record 35 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record
# Processing Record 3 of Set 4 | tuktoyaktuk
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | clyde river
# Processing Record 6 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 4 | saint george
# Processing Record 8 of Set 4 | puerto ayora
# Processing Record 9 of Set 4 | tiksi
# Processing Record 10 of Set 4 | caravelas
# Processing Record 11 of Set 4 | archidona
# Processing Record 12 of Set 4 | north platte
# Processing Record 13 of Set 4 | coos bay
# Processing Record 14 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 4 | constitucion
# Processing Record 16 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 17 of Set 4 | lompoc
# Processing Record 18 of Set 4 | leningradskiy
# Processing Record 19 of Set 4 | luderitz
# Processing Record 20 of Set 4 | surt
# Processing Record 21 of Set 4 | karpogory
# Processing Record 22 of Set 4 | saldanha
# Processing Record 23 of Set 4 | kyaikkami
# Processing Record 24 of Set 4 | cuenca
# Processing Record 25 of Set 4 | chokurdakh
# Processing Record 26 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 4 | muros
# Processing Record 28 of Set 4 | tasiilaq
# Processing Record 29 of Set 4 | aloleng
# Processing Record 30 of Set 4 | avera
# Processing Record 31 of Set 4 | bredasdorp
# Processing Record 32 of Set 4 | college
# Processing Record 33 of Set 4 | salalah
# Processing Record 34 of Set 4 | port hedland
# Processing Record 35 of Set 4 | srednekolymsk
# Processing Record 36 of Set 4 | mokhsogollokh
# Processing Record 37 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 4 | kasaragod
# Processing Record 39 of Set 4 | omsukchan
# Processing Record 40 of Set 4 | palmer
# Processing Record 41 of Set 4 | lanzhou
# Processing Record 42 of Set 4 | talnakh
# Processing Record 43 of Set 4 | grand gaube
# Processing Record 44 of Set 4 | beihai
# Processing Record 45 of Set 4 | sao miguel do araguaia
# Processing Record 46 of Set 4 | siderno
# Processing Record 47 of Set 4 | bluff
# Processing Record 48 of Set 4 | inta
# Processing Record 49 of Set 4 | taoudenni
# Processing Record 0 of Set 5 | komsomolskiy
# Processing Record 1 of Set 5 | broome
# Processing Record 2 of Set 5 | miri
# Processing Record 3 of Set 5 | thompson
# Processing Record 4 of Set 5 | bichura
# Processing Record 5 of Set 5 | hofn
# Processing Record 6 of Set 5 | kpagouda
# City not found. Skipping...
# Processing Record 7 of Set 5 | portland
# Processing Record 8 of Set 5 | afyonkarahisar
# Processing Record 9 of Set 5 | isagarh
# Processing Record 10 of Set 5 | ust-omchug
# Processing Record 11 of Set 5 | laramie
# Processing Record 12 of Set 5 | maxixe
# Processing Record 13 of Set 5 | puerto princesa
# Processing Record 14 of Set 5 | tessalit
# Processing Record 15 of Set 5 | tripoli
# Processing Record 16 of Set 5 | aklavik
# Processing Record 17 of Set 5 | saint-philippe
# Processing Record 18 of Set 5 | port huron
# Processing Record 19 of Set 5 | ugoofaaru
# Processing Record 20 of Set 5 | namtsy
# Processing Record 21 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 5 | rawson
# Processing Record 23 of Set 5 | faya
# Processing Record 24 of Set 5 | gambissara
# Processing Record 25 of Set 5 | masvingo
# Processing Record 26 of Set 5 | xuchang
# Processing Record 27 of Set 5 | san quintin
# Processing Record 28 of Set 5 | dickinson
# Processing Record 29 of Set 5 | maraa
# Processing Record 30 of Set 5 | riyadh
# Processing Record 31 of Set 5 | fort nelson
# Processing Record 32 of Set 5 | husavik
# Processing Record 33 of Set 5 | djibo
# Processing Record 34 of Set 5 | los llanos de aridane
# Processing Record 35 of Set 5 | bandarbeyla
# Processing Record 36 of Set 5 | katsuura
# Processing Record 37 of Set 5 | pasighat
# Processing Record 38 of Set 5 | codrington
# Processing Record 39 of Set 5 | lyubeshiv
# City not found. Skipping...
# Processing Record 40 of Set 5 | hue
# Processing Record 41 of Set 5 | barrow
# Processing Record 42 of Set 5 | hithadhoo
# Processing Record 43 of Set 5 | da nang
# Processing Record 44 of Set 5 | dukat
# Processing Record 45 of Set 5 | victoria
# Processing Record 46 of Set 5 | mocuba
# Processing Record 47 of Set 5 | pangody
# Processing Record 48 of Set 5 | benghazi
# Processing Record 49 of Set 5 | port macquarie
# Processing Record 0 of Set 6 | laguna
# Processing Record 1 of Set 6 | port-gentil
# Processing Record 2 of Set 6 | sitka
# Processing Record 3 of Set 6 | west bay
# Processing Record 4 of Set 6 | alugan
# Processing Record 5 of Set 6 | san andres
# Processing Record 6 of Set 6 | banyo
# Processing Record 7 of Set 6 | yazman
# Processing Record 8 of Set 6 | trogir
# Processing Record 9 of Set 6 | tadine
# Processing Record 10 of Set 6 | cockburn town
# Processing Record 11 of Set 6 | dera din panah
# City not found. Skipping...
# Processing Record 12 of Set 6 | mitoc
# Processing Record 13 of Set 6 | wladyslawowo
# Processing Record 14 of Set 6 | talakan
# Processing Record 15 of Set 6 | lata
# Processing Record 16 of Set 6 | diamantino
# Processing Record 17 of Set 6 | bolshoy uluy
# City not found. Skipping...
# Processing Record 18 of Set 6 | camopi
# Processing Record 19 of Set 6 | kokkola
# Processing Record 20 of Set 6 | san patricio
# Processing Record 21 of Set 6 | katete
# Processing Record 22 of Set 6 | samthar
# Processing Record 23 of Set 6 | chapais
# Processing Record 24 of Set 6 | pilar
# Processing Record 25 of Set 6 | oksfjord
# Processing Record 26 of Set 6 | kodiak
# Processing Record 27 of Set 6 | qaanaaq
# Processing Record 28 of Set 6 | sao filipe
# Processing Record 29 of Set 6 | wangou
# Processing Record 30 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 6 | linxia
# Processing Record 32 of Set 6 | monrovia
# Processing Record 33 of Set 6 | touros
# Processing Record 34 of Set 6 | upernavik
# Processing Record 35 of Set 6 | santa barbara
# Processing Record 36 of Set 6 | baruun-urt
# Processing Record 37 of Set 6 | nuuk
# Processing Record 38 of Set 6 | tayoltita
# Processing Record 39 of Set 6 | eureka
# Processing Record 40 of Set 6 | kudahuvadhoo
# Processing Record 41 of Set 6 | barrhead
# Processing Record 42 of Set 6 | jiayuguan
# Processing Record 43 of Set 6 | mahebourg
# Processing Record 44 of Set 6 | aripuana
# Processing Record 45 of Set 6 | harper
# Processing Record 46 of Set 6 | bangassou
# Processing Record 47 of Set 6 | bintulu
# Processing Record 48 of Set 6 | batemans bay
# Processing Record 49 of Set 6 | marsh harbour
# Processing Record 0 of Set 7 | mago
# Processing Record 1 of Set 7 | torbay
# Processing Record 2 of Set 7 | sabang
# Processing Record 3 of Set 7 | ponta do sol
# Processing Record 4 of Set 7 | amga
# Processing Record 5 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record
# Processing Record 42 of Set 9 | kalmunai
# Processing Record 43 of Set 9 | sola
# Processing Record 44 of Set 9 | fort dodge
# Processing Record 45 of Set 9 | bathsheba
# Processing Record 46 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 47 of Set 9 | zhanakorgan
# Processing Record 48 of Set 9 | evensk
# Processing Record 49 of Set 9 | manyana
# Processing Record 0 of Set 10 | tezu
# Processing Record 1 of Set 10 | volovo
# Processing Record 2 of Set 10 | dingle
# Processing Record 3 of Set 10 | novochernorechenskiy
# Processing Record 4 of Set 10 | vila franca do campo
# Processing Record 5 of Set 10 | kargasok
# Processing Record 6 of Set 10 | alcaudete
# Processing Record 7 of Set 10 | bitung
# Processing Record 8 of Set 10 | christchurch
# Processing Record 9 of Set 10 | sumbawanga
# Processing Record 10 of Set 10 | darab
# Processing Record 11 of Set 10 | islamkot
# Processing Record 12 of Set 10 | kupang
# Processing Record 13 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 14 of Set 10 | darhan
# Processing Record 15 of Set 10 | qandahar
# City not found. Skipping...
# Processing Record 16 of Set 10 | haines junction
# Processing Record 17 of Set 10 | amahai
# Processing Record 18 of Set 10 | sandviken
# Processing Record 19 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 10 | klaksvik
# Processing Record 21 of Set 10 | sakakah
# Processing Record 22 of Set 10 | magugu
# Processing Record 23 of Set 10 | malpe
# Processing Record 24 of Set 10 | gobabis
# Processing Record 25 of Set 10 | kahului
# Processing Record 26 of Set 10 | linqiong
# Processing Record 27 of Set 10 | alofi
# Processing Record 28 of Set 10 | suntar
# Processing Record 29 of Set 10 | teguldet
# Processing Record 30 of Set 10 | flinders
# Processing Record 31 of Set 10 | goulburn
# Processing Record 32 of Set 10 | campbell river
# Processing Record 33 of Set 10 | batagay-alyta
# Processing Record 34 of Set 10 | high level
# Processing Record 35 of Set 10 | nanakuli
# Processing Record 36 of Set 10 | ferrol
# Processing Record 37 of Set 10 | tamluk
# Processing Record 38 of Set 10 | sorland
# Processing Record 39 of Set 10 | ploemeur
# Processing Record 40 of Set 10 | zapolyarnyy
# Processing Record 41 of Set 10 | kailua
# Processing Record 42 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 10 | shestakovo
# Processing Record 44 of Set 10 | alice springs
# Processing Record 45 of Set 10 | alta floresta
# Processing Record 46 of Set 10 | bejar
# Processing Record 47 of Set 10 | porto novo
# Processing Record 48 of Set 10 | ambilobe
# Processing Record 49 of Set 10 | yinchuan
# Processing Record 0 of Set 11 | kenai
# Processing Record 1 of Set 11 | puerto leguizamo
# Processing Record 2 of Set 11 | itarema
# Processing Record 3 of Set 11 | pietarsaari
# Processing Record 4 of Set 11 | saint-georges
# Processing Record 5 of Set 11 | rio brilhante
# Processing Record 6 of Set 11 | rio gallegos
# Processing Record 7 of Set 11 | samarai
# Processing Record 8 of Set 11 | cam ranh
# Processing Record 9 of Set 11 | valpoi
# Processing Record 10 of Set 11 | freeport
# Processing Record 11 of Set 11 | luanda
# Processing Record 12 of Set 11 | mount isa
# Processing Record 13 of Set 11 | yar-sale
# Processing Record 14 of Set 11 | makakilo city
# Processing Record 15 of Set 11 | bogande
# Processing Record 16 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 17 of Set 11 | khomeyn
# Processing Record 18 of Set 11 | soller
# Processing Record 19 of Set 11 | nanortalik
# Processing Record 20 of Set 11 | shanghai
# Processing Record 21 of Set 11 | calvinia
# Processing Record 22 of Set 11 | moron
# Processing Record 23 of Set 11 | stornoway
# Processing Record 24 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 25 of Set 11 | ulladulla
# Processing Record 26 of Set 11 | yaan
# Processing Record 27 of Set 11 | panalingaan
# Processing Record 28 of Set 11 | bongandanga
# Processing Record 29 of Set 11 | geraldton
# Processing Record 30 of Set 11 | anar darreh
# City not found. Skipping...
# Processing Record 31 of Set 11 | labytnangi
# Processing Record 32 of Set 11 | richards bay
# Processing Record 33 of Set 11 | turayf
# Processing Record 34 of Set 11 | sur
# Processing Record 35 of Set 11 | thunder bay
# Processing Record 36 of Set 11 | skibbereen
# Processing Record 37 of Set 11 | peniche
# Processing Record 38 of Set 11 | oussouye
# Processing Record 39 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 41 of Set 11 | lomita
# Processing Record 42 of Set 11 | coquimbo
# Processing Record 43 of Set 11 | abong mbang
# Processing Record 44 of Set 11 | comodoro rivadavia
# Processing Record 45 of Set 11 | tommot
# Processing Record 46 of Set 11 | fukue
# Processing Record 47 of Set 11 | maloy
# Processing Record 48 of Set 11 | pafos
# Processing Record 49 of Set 11 | chiang khong
# Processing Record 0 of Set 12 | omboue
# Processing Record 1 of Set 12 | brae
# Processing Record 2 of Set 12 | aksu
# Processing Record 3 of Set 12 | lufilufi
# Processing Record 4 of Set 12 | kampot
# Processing Record 5 of Set 12 | itaituba
# Processing Record 6 of Set 12 | anadyr
# Processing Record 7 of Set 12 | yarada
# Processing Record 8 of Set 12 | boli
# Processing Record 9 of Set 12 | rocha
# Processing Record 10 of Set 12 | bilibino
# Processing Record 11 of Set 12 | nantucket
# Processing Record 12 of Set 12 | saint anthony
# Processing Record 13 of Set 12 | yeppoon
# Processing Record 14 of Set 12 | akhmeta
# Processing Record 15 of Set 12 | beeville
# Processing Record 16 of Set 12 | tura
# Processing Record 17 of Set 12 | cherskiy
# Processing Record 18 of Set 12 | payo
# Processing Record 19 of Set 12 | safford
# Processing Record 20 of Set 12 | churapcha
# Processing Record 21 of Set 12 | akcaabat
# Processing Record 22 of Set 12 | flin flon
# Processing Record 23 of Set 12 | puerto narino
# Processing Record 24 of Set 12 | chihuahua
# Processing Record 25 of Set 12 | prince rupert
# Processing Record 26 of Set 12 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 27 of Set 12 | sungairaya
# Processing Record 28 of Set 12 | acarau
# Processing Record 29 of Set 12 | tonder
# Processing Record 30 of Set 12 | kisangani
# Processing Record 31 of Set 12 | cachoeiras de macacu
# Processing Record 32 of Set 12 | anicuns
# Processing Record 33 of Set 12 | bethanien
# Processing Record 34 of Set 12 | rusape
# Processing Record 35 of Set 12 | atambua
# Processing Record 36 of Set 12 | aguimes
# Processing Record 37 of Set 12 | itoman
# Processing Record 38 of Set 12 | udachnyy
# Processing Record 39 of Set 12 | zaraza
# Processing Record 40 of Set 12 | turukhansk
# Processing Record 41 of Set 12 | mapiripan
# Processing Record 42 of Set 12 | three hills
# Processing Record 43 of Set 12 | noyakert
# Processing Record 44 of Set 12 | sisimiut
# Processing Record 45 of Set 12 | el paso
# Processing Record 46 of Set 12 | luwingu
# Processing Record 47 of Set 12 | saint-francois
# Processing Record 48 of Set 12 | new philadelphia
# Processing Record 49 of Set 12 | pitimbu
# Processing Record 0 of Set 13 | shush
# Processing Record 1 of Set 13 | buta
# Processing Record 2 of Set 13 | dzerzhinsk
# Processing Record 3 of Set 13 | mandalay
# Processing Record 4 of Set 13 | nizwa
# Processing Record 5 of Set 13 | aviles
# Processing Record 6 of Set 13 | mayo
# Processing Record 7 of Set 13 | ayan
# Processing Record 8 of Set 13 | hualmay
# Processing Record 9 of Set 13 | saint-augustin
# Processing Record 10 of Set 13 | tocopilla
# Processing Record 11 of Set 13 | macklin
# Processing Record 12 of Set 13 | vestmanna
# Processing Record 13 of Set 13 | pangnirtung
# Processing Record 14 of Set 13 | manakara
# Processing Record 15 of Set 13 | rafaela
# Processing Record 16 of Set 13 | kizner
# Processing Record 17 of Set 13 | markova
# Processing Record 18 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 19 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 20 of Set 13 | waidhofen
# Processing Record 21 of Set 13 | xinmin
# Processing Record 22 of Set 13 | pelym
# Processing Record 23 of Set 13 | caraballeda
# Processing Record 24 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 13 | ksenyevka
# City not found. Skipping...
# Processing Record 26 of Set 13 | abu zabad
# Processing Record 27 of Set 13 | killam
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          578
# Lat           578
# Lng           578
# Max Temp      578
# Humidity      578
# Cloudiness    578
# Wind Speed    578
# Country       578
# Date          578
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          lebu -37.6167 -73.6500     57.11        57           0       25.32
# 1  punta arenas -53.1500 -70.9167     53.71        50          40       32.21
# 2    sheltozero  61.3667  35.3667     22.95        81           4        6.58
# 3      damaturu  11.7470  11.9608     79.75        23          11        9.91
# 4           ilo -17.6394 -71.3375     66.65        77          80        3.87
#
#   Country        Date
# 0      CL  1668967896
# 1      CL  1668967896
# 2      RU  1668967896
# 3      NG  1668967897
# 4      PE  1668967897

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                lebu -37.6167 -73.6500     57.11        57           0
# 1        punta arenas -53.1500 -70.9167     53.71        50          40
# 2          sheltozero  61.3667  35.3667     22.95        81           4
# 3            damaturu  11.7470  11.9608     79.75        23          11
# 4                 ilo -17.6394 -71.3375     66.65        77          80
#
#          Wind Speed Country        Date
# City_ID
# 0             25.32      CL  1668967896
# 1             32.21      CL  1668967896
# 2              6.58      RU  1668967896
# 3              9.91      NG  1668967897
# 4              3.87      PE  1668967897

# %% [markdown]
# **Create the Scatter Plots Requested**
# **Latitude Vs. Temperature**

# %% [markdown]
# There is a negative correlation between the lattitude and the temperature.  As the latitude increases, the temperature decreases.

# %%
lat = city_data_df["Lat"]
max_temp = city_data_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, max_temp)
regress_values = lat * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(lat, max_temp, marker="o", color="blue", alpha = 0.5)
plt.plot(lat, regress_values, color='black')
plt.annotate(line_eq,(-40,0), fontsize=14)

# Incorporate the other graph properties
plt.title("City Latitude vs. Temperature 11-20-2022")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-squared is: {round(rvalue**2,3)}")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
#plt.savefig("output_data/Fig1.png")

# Show plot
#plt.show()
# Out:
# The r-squared is: 0.516

# %% [markdown]
# **Latitude Vs. Humidity**
#
# There is a slight positive correlation between the latitude and the humidity.  As the latitude increase, the humidity increases.

# %%
humidity = city_data_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(lat, humidity)
regress_values = lat * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(lat, humidity, marker="o", color="green", alpha = 0.5)
plt.plot(lat, regress_values, color='black')
plt.annotate(line_eq,(22,15), fontsize=14)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity 11-20-2022")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {round(rvalue**2,3)}")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
#plt.savefig("output_data/Fig2.png")

# Show plot
#plt.show()
# Out:
# The r-squared is: 0.069

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %% [markdown]
# There is a slight positive correlation between latitude and cloudiness.  As latitude increases, cloudiness increases.

# %%
cloudiness = city_data_df["Cloudiness"]
(slope, intercept,rvalue, pvalue, stderr) = linregress(lat, cloudiness)
regress_values = lat * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(lat, cloudiness, marker="o", color="gray", alpha = 0.5)
plt.plot(lat, regress_values, color='black')
plt.annotate(line_eq,(26,41), fontsize=14)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness 11-20-2022")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {round(rvalue**2,3)}")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
#plt.savefig("output_data/Fig3.png")

# Show plot
#plt.show()
# Out:
# The r-squared is: 0.019

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# There is a slight negative correlaton between latitude and wind speed.  As latitude increases, wind speed decreases.

# %%
wind_speed = city_data_df["Wind Speed"]
(slope, intercept,rvalue, pvalue, stderr) = linregress(lat, wind_speed)
regress_values = lat * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(lat, wind_speed, marker="o", color="red", alpha = 0.5)
plt.plot(lat, regress_values, color='black')
plt.annotate(line_eq,(-40,30), fontsize=14)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed 11-20-2022")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
print(f"The r-squared is: {round(rvalue**2,3)}")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
#plt.savefig("output_data/Fig4.png")

# Show plot
#plt.show()
# Out:
# The r-squared is: 0.021

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0, :]


# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        sheltozero  61.3667   35.3667     22.95        81           4
# 3          damaturu  11.7470   11.9608     79.75        23          11
# 5        solnechnyy  50.7214  136.6319     19.67        88          20
# 6              nome  64.5011 -165.4064     33.87        69          40
# 7             qeshm  26.9581   56.2719     80.47        70           0
#
#          Wind Speed Country        Date
# City_ID
# 2              6.58      RU  1668967896
# 3              9.91      NG  1668967897
# 5              4.63      RU  1668967897
# 6              8.05      US  1668967898
# 7              8.70      IR  1668967898

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  lebu -37.6167 -73.6500     57.11        57           0
# 1          punta arenas -53.1500 -70.9167     53.71        50          40
# 4                   ilo -17.6394 -71.3375     66.65        77          80
# 9        port elizabeth -33.9180  25.5701     63.10        77          29
# 10        mar del plata -38.0023 -57.5575     65.08        94         100
#
#          Wind Speed Country        Date
# City_ID
# 0             25.32      CL  1668967896
# 1             32.21      CL  1668967896
# 4              3.87      PE  1668967897
# 9              3.18      ZA  1668967898
# 10            14.97      AR  1668967899

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %% [markdown]
# There is a strong negative correlation between the latitude in the northern hemisphere and the temperature.  As the latitude increases, the temperature decreases.

# %%
northern_lat = northern_hemi_df["Lat"]
northern_max_temp = northern_hemi_df["Max Temp"]
(slope, intercept,rvalue, pvalue, stderr) = linregress(northern_lat, northern_max_temp)
regress_values = nlat * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(northern_lat, northern_max_temp, marker="o", color="blue", alpha = 0.5)
plt.plot(northern_lat, regress_values, color='black')
plt.annotate(line_eq,(10,0), fontsize=14)

# Incorporate the other graph properties
plt.title("Northern Hemisphere City Latitude vs. Temperature 11-20-22")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {round(rvalue**2,3)}")
print(line_eq)

# Save the figure
plt.savefig("output_data/Fig5.png")

# Show plot
plt.show()
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-squared is: 0.752
# y = -1.3 x + 96.33

# %%
southern_lat = southern_hemi_df["Lat"]
southern_max_temp = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_lat, smax_temp)
regress_values = southern_lat * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(southern_lat, southern_max_temp, marker="o", color="red", alpha = 0.5)
plt.plot(southern_lat, regress_values, color='black')
plt.annotate(line_eq,(-50,92), fontsize=14, color='black')

# Incorporate the other graph properties
plt.title("Southern Hemisphere City Latitude vs. Temperature 11-20-22")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {round(rvalue**2,3)}")
print(line_eq)

# Save the figure
plt.savefig("output_data/Fig6.png")

# Show plot
plt.show()
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-squared is: 0.396
# y = 0.54 x + 83.95

# %% [markdown]
# **Discussion about the linear relationship:** As you move closer to the equater (0) it gets hotter.  There is a positive correlation between your proximity to the equater and the temperature increasing.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
northern_lat = northern_hemi_df["Lat"]
northern_humidity = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_lat, northern_humidity)
regress_values = northern_lat * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(northern_lat, northern_humidity, marker="o", color="blue", alpha = 0.5)
plt.plot(northern_lat, regress_values, color='black')
plt.annotate(line_eq,(47,20), fontsize=14, color='black')

# Incorporate the other graph properties
plt.title("Northern Hemisphere City Latitude vs. Humidity 11-20-2022")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {round(rvalue**2,3)}")
print(line_eq)

# Save the figure
plt.savefig("output_data/Fig7.png")

# Show plot
plt.show()
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-squared is: 0.164
# y = 0.46 x + 53.38

# %%
southern_lat = southern_hemi_df["Lat"]
southern_humidity = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_lat, southern_humidity)
regress_values = southern_lat * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(southern_lat, southern_humidity, marker="o", color="red", alpha = 0.5)
plt.plot(southern_lat, regress_values, color='black')
plt.annotate(line_eq,(-50,30), fontsize=14, color='black')

# Incorporate the other graph properties
plt.title("Southern Hemisphere City Latitude vs. Humidity 11-20-2022")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {round(rvalue**2,3)}")
print(line_eq)

# Save the figure
plt.savefig("output_data/Fig8.png")

# Show plot
plt.show()
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-squared is: 0.011
# y = 0.16 x + 70.53

# %% [markdown]
# **Discussion about the linear relationship:** There is a positive correlation in both the northern and southern hemispheres between the latitude and the humidity.   The humidity in the southern hemisphere averages around 70%.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
northern_lat = northern_hemi_df["Lat"]
northern_cloudiness = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_lat, northern_cloudiness)
regress_values = northern_lat * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(northern_lat, northern_cloudiness, marker="o", color="blue", alpha = 0.5)
plt.plot(northern_lat, regress_values, color='black')
plt.annotate(line_eq,(33,45), fontsize=14, color='black')

# Incorporate the other graph properties
plt.title("Northern Hemisphere City Latitude vs. Cloudiness 11-20-2022")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {round(rvalue**2,3)}")
print(line_eq)

# Save the figure
plt.savefig("output_data/Fig9.png")

# Show plot
plt.show()
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-squared is: 0.036
# y = 0.37 x + 45.23

# %%
southern_lat = southern_hemi_df["Lat"]
southern_cloudiness = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_lat, southern_cloudiness)
regress_values = southern_lat * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(southern_lat, southern_cloudiness, marker="o", color="red", alpha = 0.5)
plt.plot(southern_lat, regress_values, color='black')
plt.annotate(line_eq,(-55,65), fontsize=14, color='black')

# Incorporate the other graph properties
plt.title("Southern Hemisphere City Latitude vs. Cloudiness 11-20-2022")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {round(rvalue**2,3)}")
print(line_eq)

# Save the figure
plt.savefig("output_data/Fig10.png")

# Show plot
plt.show()
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-squared is: 0.025
# y = 0.4 x + 64.32

# %% [markdown]
# **Discussion about the linear relationship:** There is a positive correlation in both hemispheres between the latitude and the cloudiness.  The data in the northern hemisphere appears more scattered than the southern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
northern_lat = northern_hemi_df["Lat"]
northern_wind_speed = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_lat, northern_wind_speed)
regress_values = northern_lat * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(northern_lat, northern_wind_speed, marker="o", color="blue", alpha = 0.5)
plt.plot(northern_lat, regress_values, color='black')
plt.annotate(line_eq,(10,30), fontsize=14, color='black')

# Incorporate the other graph properties
plt.title("Northern Hemisphere City Latitude vs. Wind Speed 11-20-2022")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {round(rvalue**2,3)}")
print(line_eq)

# Save the figure
plt.savefig("output_data/Fig11.png")

# Show plot
plt.show()
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-squared is: 0.0
# y = -0.0 x + 7.73

# %%
southern_lat = southern_hemi_df["Lat"]
southern_wind_speed = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_lat, southern_wind_speed)
regress_values = southern_lat * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(southern_lat, southern_wind_speed, marker="o", color="red", alpha = 0.5)
plt.plot(southern_lat, regress_values, color='black')
plt.annotate(line_eq,(-20,30), fontsize=14, color='black')

# Incorporate the other graph properties
plt.title("Southern Hemisphere City Latitude vs. Wind Speed 11-20-2022")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {round(rvalue**2,3)}")
print(line_eq)

# Save the figure
plt.savefig("output_data/Fig12.png")

# Show plot
plt.show()
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-squared is: 0.146
# y = -0.17 x + 5.6

# %% [markdown]
# **Discussion about the linear relationship:** The wind spead in the nothern hemisphere is more constant at around 7.  The wind speed in the southern hemisphere has a negative correlation as the wind decreases as the latitude increases.
